# %% [markdown]
# <a href="https://colab.research.google.com/github/cheolsoon0604/RNE/blob/main/rnefinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

img1 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/1.jpg")
image1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
image01 = np.asarray(cv2.calcHist([image1], [0], None, [256], [0, 256]), dtype=np.int64)

img2 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/2.jpg")
image2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
image02 = np.asarray(cv2.calcHist([image2], [0], None, [256], [0, 256]), dtype=np.int64)

img3 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/3.jpg")
image3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
image03 = np.asarray(cv2.calcHist([image3], [0], None, [256], [0, 256]), dtype=np.int64)

img4 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/4.jpg")
image4 = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
image04 = np.asarray(cv2.calcHist([image4], [0], None, [256], [0, 256]), dtype=np.int64)

img5 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/5.jpg")
image5 = cv2.cvtColor(img5, cv2.COLOR_BGR2GRAY)
image05 = np.asarray(cv2.calcHist([image5], [0], None, [256], [0, 256]), dtype=np.int64)

img6 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/6.jpg")
image6 = cv2.cvtColor(img6, cv2.COLOR_BGR2GRAY)
image06 = np.asarray(cv2.calcHist([image6], [0], None, [256], [0, 256]), dtype=np.int64)

img7 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/7.jpg")
image7 = cv2.cvtColor(img7, cv2.COLOR_BGR2GRAY)
image07 = np.asarray(cv2.calcHist([image7], [0], None, [256], [0, 256]), dtype=np.int64)

img8 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/8.jpg")
image8 = cv2.cvtColor(img8, cv2.COLOR_BGR2GRAY)
image08 = np.asarray(cv2.calcHist([image8], [0], None, [256], [0, 256]), dtype=np.int64)

img9 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/11.jpg")
image9 = cv2.cvtColor(img9, cv2.COLOR_BGR2GRAY)
image09 = np.asarray(cv2.calcHist([image9], [0], None, [256], [0, 256]), dtype=np.int64)

img10 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/12.jpg")
image10 = cv2.cvtColor(img10, cv2.COLOR_BGR2GRAY)
image010 = np.asarray(cv2.calcHist([image10], [0], None, [256], [0, 256]), dtype=np.int64)

img11 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/13.jpg")
image11 = cv2.cvtColor(img11, cv2.COLOR_BGR2GRAY)
image011 = np.asarray(cv2.calcHist([image11], [0], None, [256], [0, 256]), dtype=np.int64)

img12 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/14.jpg")
image12 = cv2.cvtColor(img12, cv2.COLOR_BGR2GRAY)
image012 = np.asarray(cv2.calcHist([image12], [0], None, [256], [0, 256]), dtype=np.int64)

img13 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/15.jpg")
image13 = cv2.cvtColor(img13, cv2.COLOR_BGR2GRAY)
image013 = np.asarray(cv2.calcHist([image13], [0], None, [256], [0, 256]), dtype=np.int64)

img14 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/16.jpg")
image14 = cv2.cvtColor(img14, cv2.COLOR_BGR2GRAY)
image014 = np.asarray(cv2.calcHist([image14], [0], None, [256], [0, 256]), dtype=np.int64)

img15 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/17.jpg")
image15 = cv2.cvtColor(img15, cv2.COLOR_BGR2GRAY)
image015 = np.asarray(cv2.calcHist([image15], [0], None, [256], [0, 256]), dtype=np.int64)

img16 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/18.jpg")
image16 = cv2.cvtColor(img16, cv2.COLOR_BGR2GRAY)
image016 = np.asarray(cv2.calcHist([image16], [0], None, [256], [0, 256]), dtype=np.int64)

img17 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/21.jpg")
image17 = cv2.cvtColor(img17, cv2.COLOR_BGR2GRAY)
image017 = np.asarray(cv2.calcHist([image17], [0], None, [256], [0, 256]), dtype=np.int64)

img18 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/22.jpg")
image18 = cv2.cvtColor(img18, cv2.COLOR_BGR2GRAY)
image018 = np.asarray(cv2.calcHist([image18], [0], None, [256], [0, 256]), dtype=np.int64)

img19 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/23.jpg")
image19 = cv2.cvtColor(img19, cv2.COLOR_BGR2GRAY)
image019 = np.asarray(cv2.calcHist([image19], [0], None, [256], [0, 256]), dtype=np.int64)

img20 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/24.jpg")
image20 = cv2.cvtColor(img20, cv2.COLOR_BGR2GRAY)
image020 = np.asarray(cv2.calcHist([image20], [0], None, [256], [0, 256]), dtype=np.int64)

img21 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/25.jpg")
image21 = cv2.cvtColor(img21, cv2.COLOR_BGR2GRAY)
image021 = np.asarray(cv2.calcHist([image21], [0], None, [256], [0, 256]), dtype=np.int64)

img22 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/26.jpg")
image22 = cv2.cvtColor(img22, cv2.COLOR_BGR2GRAY)
image022 = np.asarray(cv2.calcHist([image22], [0], None, [256], [0, 256]), dtype=np.int64)

img23 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/27.jpg")
image23 = cv2.cvtColor(img23, cv2.COLOR_BGR2GRAY)
image023 = np.asarray(cv2.calcHist([image23], [0], None, [256], [0, 256]), dtype=np.int64)

img24 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/28.jpg")
image24 = cv2.cvtColor(img24, cv2.COLOR_BGR2GRAY)
image024 = np.asarray(cv2.calcHist([image24], [0], None, [256], [0, 256]), dtype=np.int64)

img25 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/31.jpg")
image25 = cv2.cvtColor(img25, cv2.COLOR_BGR2GRAY)
image025 = np.asarray(cv2.calcHist([image25], [0], None, [256], [0, 256]), dtype=np.int64)

img26 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/32.jpg")
image26 = cv2.cvtColor(img26, cv2.COLOR_BGR2GRAY)
image026 = np.asarray(cv2.calcHist([image26], [0], None, [256], [0, 256]), dtype=np.int64)

img27 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/33.jpg")
image27 = cv2.cvtColor(img27, cv2.COLOR_BGR2GRAY)
image027 = np.asarray(cv2.calcHist([image27], [0], None, [256], [0, 256]), dtype=np.int64)

img28 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/34.jpg")
image28 = cv2.cvtColor(img28, cv2.COLOR_BGR2GRAY)
image028 = np.asarray(cv2.calcHist([image28], [0], None, [256], [0, 256]), dtype=np.int64)

img29 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/35.jpg")
image29 = cv2.cvtColor(img29, cv2.COLOR_BGR2GRAY)
image029 = np.asarray(cv2.calcHist([image29], [0], None, [256], [0, 256]), dtype=np.int64)

img30 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/36.jpg")
image30 = cv2.cvtColor(img30, cv2.COLOR_BGR2GRAY)
image030 = np.asarray(cv2.calcHist([image30], [0], None, [256], [0, 256]), dtype=np.int64)

img31 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/37.jpg")
image31 = cv2.cvtColor(img31, cv2.COLOR_BGR2GRAY)
image031 = np.asarray(cv2.calcHist([image31], [0], None, [256], [0, 256]), dtype=np.int64)

img32 = cv2.imread("/content/drive/MyDrive/ice/lowtemp/2/38.jpg")
image32 = cv2.cvtColor(img32, cv2.COLOR_BGR2GRAY)
image032 = np.asarray(cv2.calcHist([image32], [0], None, [256], [0, 256]), dtype=np.int64)

images = pd.DataFrame(
    {
        '1': [image01],
        '2': [image02],
        '3': [image03],
        '4': [image04],
        '5': [image05],
        '6': [image06],
        '7': [image07],
        '8': [image08],
        '9': [image09],
        '10': [image010],
        '11': [image011],
        '12': [image012],
        '13': [image013],
        '14': [image014],
        '15': [image015],
        '16': [image016],
        '17': [image017],
        '18': [image018],
        '19': [image019],
        '20': [image020],
        '21': [image021],
        '22': [image022],
        '23': [image023],
        '24': [image024],
        '25': [image025],
        '26': [image026],
        '27': [image027],
        '28': [image028],
        '29': [image029],
        '30': [image030],
        '31': [image031],
        '32': [image032],
        '33': [image033]
    }
)


images.to_excel('/content/drive/My Drive/lowtempdata.xlsx')
